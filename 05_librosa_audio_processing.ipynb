# %%
import librosa
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import soundfile as sf
import matplotlib.pyplot as plt
import os

# %%
file_path=r"C:/Users/Ozair/Downloads/Conference.wav"
def extract_features(file_path):
  
    try:
        signal, sr = librosa.load(file_path, sr=None)
        
        mfccs = librosa.feature.mfcc(y=signal, sr=sr, n_mfcc=13)
        mfcc_mean = np.mean(mfccs, axis=1)
        mfcc_std = np.std(mfccs, axis=1)
        
        spectrum = np.abs(np.fft.fft(signal))
        log_spectrum = np.log(spectrum + 1e-10) 
        cepstrum = np.real(np.fft.ifft(log_spectrum))[:13]
        
        return np.concatenate([mfcc_mean, mfcc_std, cepstrum])
    
    except Exception as e:
        print(f"Error processing {file_path}: {str(e)}")
        return None
    
directory_path=r"C:\Users\Ozair\Downloads\rec"
def process_directory(directory_path):
    
    features = []
    file_names = []
    
    audio_extensions = ('.ogg', '.wav', '.mp3', '.flac')
    
    if not os.path.exists(directory_path):
        print(f"Directory not found: {directory_path}")
        return None
    
audio_extensions = ('.ogg', '.wav', '.mp3', '.flac')

for file in os.listdir(directory_path):
    if file.lower().endswith(audio_extensions):
        file_path = os.path.join(directory_path, file)
        print(f"Processing: {file_path}")
            
            
    feature_vector = extract_features(file_path)
    if feature_vector is not None:
        features.append(feature_vector)
        file_names.append(file)
    
    if not features:
        print("No valid audio files found or features extracted!")
return None
    
return np.array(features), file_names

if __name__ == "__main__":
    audio_dir = "C:/Users/Ozair/Downloads/rec"
    features, file_names = process_directory(audio_dir)
    
    if features is not None:
        print(f"\nSuccessfully extracted features from {len(features)} files:")
        for name, feature in zip(file_names, features):
            print(f"{name}: Feature vector length {len(feature)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 43
#      41 feature_vector = extract_features(file_path)
#      42 if feature_vector is not None:
# ---> 43     features.append(feature_vector)
#      44     file_names.append(file)
#      46 if not features:
#
# NameError: name 'features' is not defined

# %%
file_path=r"C:/Users/Ozair/Downloads/Conference.wav"
directory_path=r"C:\Users\Ozair\Downloads\rec"

def extract_features(file_path):
    try:
        signal, sr = librosa.load(file_path, sr=None)
        
        mfccs = librosa.feature.mfcc(y=signal, sr=sr, n_mfcc=13)
        mfcc_mean = np.mean(mfccs, axis=1)
        mfcc_std = np.std(mfccs, axis=1)
        
        spectrum = np.abs(np.fft.fft(signal))
        log_spectrum = np.log(spectrum + 1e-10) 
        cepstrum = np.real(np.fft.ifft(log_spectrum))[:13]
        
        return np.concatenate([mfcc_mean, mfcc_std, cepstrum])
    
    except Exception as e:
        print(f"Error processing {file_path}: {str(e)}")
        return None

def process_directory(directory_path):
    features = []
    file_names = []
    audio_extensions = ('.ogg', '.wav', '.mp3', '.flac')
    
    if not os.path.exists(directory_path):
        print(f"Directory not found: {directory_path}")
        return None, None
    
    for file in os.listdir(directory_path):
        if file.lower().endswith(audio_extensions):
            file_path = os.path.join(directory_path, file)
            print(f"Processing: {file_path}")
            
            feature_vector = extract_features(file_path)
            if feature_vector is not None:
                features.append(feature_vector)
                file_names.append(file)
    
    if not features:
        print("No valid audio files found or features extracted!")
        return None, None
    
    return np.array(features), file_names

if __name__ == "__main__":
    audio_dir = r"C:\Users\Ozair\Downloads\rec"
    features, file_names = process_directory(audio_dir)
    
    if features is not None:
        print(f"\nSuccessfully extracted features from {len(features)} files:")
        for name, feature in zip(file_names, features):
            print(f"{name}: Feature vector length {len(feature)}")
# Out:
# No valid audio files found or features extracted!
